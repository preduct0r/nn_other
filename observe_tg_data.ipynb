# %%
import pandas as pd

# %%
telegram_data = pd.read_csv('~/Documents/Nornikel/telegram_messages.csv')
telegram_data
# Out:
#                             time           sender  \
# 0      2023-10-31 22:25:48+03:00    Anton Abrarov
# 1      2023-11-03 13:09:24+03:00    Anton Abrarov
# 2      2023-11-03 13:42:58+03:00    Pavel Danilov
# 3      2023-11-03 13:43:55+03:00    Anton Abrarov
# 4      2023-11-03 13:44:10+03:00    Pavel Danilov
# ...                          ...              ...
# 34557  2025-05-14 13:23:15+03:00  Иван Запорожцев
# 34558  2025-05-14 13:24:15+03:00           System
# 34559  2025-05-14 13:24:28+03:00           System
# 34560  2025-05-14 14:01:49+03:00  Иван Запорожцев
# 34561  2025-05-14 14:07:10+03:00         Yaroslav
#
#                                                     text           topic
# 0                                                     Yo         Group 1
# 1      Всем привет, новая версия чата, про которую го...         Group 1
# 2                             А можно флудилку добавить?         Group 1
# ...

# %%
telegram_data[telegram_data['sender'].isin(['Ольга Романова', 'Ольга'])]
# Out:
# Empty DataFrame
# Columns: [time, sender, text, topic]
# Index: []

# %%
set(telegram_data['sender'])
# Out:
# {'Aleksandr Chursin',
#  'Aleksandr Chursin via @PredskazBot',
#  'Alexey K',
#  'Alexey K  27.03.2025 14:00:03',
#  'Alexey K  via @PredskazBot',
#  'Anton Abrarov',
#  'Anton Abrarov 26.09.2023 13:46:37',
#  'Artem Arkhipov',
#  'Artem Arkhipov via @HowGayBot',
#  'Artem Senin',
#  'Artem Senin via @HowGayBot',
#  'Artur  03.11.2024 19:22:52',
#  'Artur  03.11.2024 19:23:07',
#  'Artur  05.10.2024 23:14:21',
#  'Artur  09.08.2024 16:17:47',
#  'Artur  13.10.2024 22:27:38',
#  'Artur  13.10.2024 22:27:59',
#  'Artur  13.11.2024 17:26:02',
#  'Artur  13.11.2024 17:33:02',
#  'Artur  13.11.2024 17:41:23',
#  'Artur  22.10.2024 23:17:13',
#  'Artur  22.10.2024 23:20:33',
#  'Artur  22.10.2024 23:20:36',
#  'Artur  22.10.2024 23:20:56',
#  'Artur  24.09.2024 00:15:40',
#  'Ateo Breaking  20.01.2025 20:53:05',
#  'Big Jesus',
#  'Big Jesus 05.02.2025 13:55:56',
#  'Calendar for Telegram',
#  'Daniil Dukhanin 22.09.2024 17:43:13',
#  'Danil Ivashechkin',
# ...
